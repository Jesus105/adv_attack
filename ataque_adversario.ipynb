# %% [markdown]
# <h1>Ataques adversarios</h1>
# <p>En este cuaderno programaremos un ataque adversario a una AI de clasifiación de imagenes.</p>

# %%
import tensorflow as tf
import keras 
import numpy as np
import matplotlib.pyplot as plt

# %%
from keras.applications.inception_v3 import InceptionV3, decode_predictions
from keras import backend as k

# %%
iv3 = InceptionV3()

# %%
from keras.preprocessing import image

x = image.img_to_array(image.load_img("./Imágenes/fakelemon.png", target_size=(299,299)))

x /= 255
x -=0.5
x *=2

x = x.reshape([1, x.shape[0],x.shape[1], x.shape[2]])

y = iv3.predict(x)

# %%
print(decode_predictions(y))
print(decode_predictions(y)[0][0][1])
# Out:
# [[('n07749582', 'lemon', 0.99823135), ('n07747607', 'orange', 0.0010298394), ('n04409515', 'tennis_ball', 0.00012066119), ('n07742313', 'Granny_Smith', 0.000115521754), ('n07753592', 'banana', 6.28453e-05)]]
# lemon

# %% [markdown]
# <p>Hasta aquí probamos que la red neuronal funciona. :)</p>

# %%
inp_layer = iv3.layers[0].input
out_layer = iv3.layers[-1].output

target_class = 951

loss = out_layer[0, target_class]

grad = k.gradients(loss, inp_layer)[0]

optimize_gradient = k.function([inp_layer, k.learning_phase()], [grad, loss])

adv = np.copy(x)

pert = 0.01

max_pert = x + 0.01
min_pert = x - 0.01

cost = 0.0

while cost < 0.95:
    gr, cost = optimize_gradient([adv, 0])
    
    adv += gr
    
    adv = np.clip(adv, min_pert, max_pert)
    adv = np.clip(adv, -1, 1)
    
    print("Target cost:", cost)
    
fake_img = np.copy(adv)
# Out:
# Target cost: 0.00010008211
# Target cost: 0.00010134203
# Target cost: 0.000102654376
# Target cost: 0.00010399238
# Target cost: 0.00010534388
# Target cost: 0.000106715765
# Target cost: 0.00010810232
# Target cost: 0.000109515844
# Target cost: 0.00011094099
# Target cost: 0.00011236911
# Target cost: 0.000113831
# Target cost: 0.00011532023
# Target cost: 0.00011683312
# Target cost: 0.00011835358
# Target cost: 0.00011988861
# Target cost: 0.000121451754
# Target cost: 0.00012302563
# Target cost: 0.00012462486
# Target cost: 0.00012625827
# Target cost: 0.000127932
# Target cost: 0.00012961435
# Target cost: 0.00013132535
# Target cost: 0.00013305424
# Target cost: 0.00013478725
# Target cost: 0.00013655891
# Target cost: 0.00013837023
# Target cost: 0.00014020884
# Target cost: 0.00014208962
# Target cost: 0.00014401069
# Target cost: 0.00014597643
# Target cost: 0.00014797604
# Target cost: 0.00015004871
# Target cost: 0.00015221447
# Target cost: 0.00015448347
# Target cost: 0.00015681039
# Target cost: 0.00015919216
# Target cost: 0.00016163822
# Target cost: 0.00016417618
# Target cost: 0.00016675386
# Target cost: 0.00016941655
# Target cost: 0.00017217753
# Target cost: 0.0001750381
# Target cost: 0.0001779431
# Target cost: 0.0001808877
# Target cost: 0.00018389334
# Target cost: 0.00018695676
# Target cost: 0.00019007677
# Target cost: 0.0001932389
# Target cost: 0.00019651584
# Target cost: 0.0001998908
# Target cost: 0.0002033736
# Target cost: 0.00020693243
# Target cost: 0.00021057276
# Target cost: 0.00021433168
# Target cost: 0.00021815911
# Target cost: 0.00022211375
# Target cost: 0.00022622036
# Target cost: 0.00023050047
# Target cost: 0.00023493449
# Target cost: 0.00023945184
# Target cost: 0.00024407916
# Target cost: 0.00024886744
# Target cost: 0.00025382897
# Target cost: 0.00025893966
# Target cost: 0.0002642599
# Target cost: 0.00026970357
# Target cost: 0.00027526962
# Target cost: 0.0002810204
# Target cost: 0.00028699203
# Target cost: 0.0002931917
# Target cost: 0.00029971497
# Target cost: 0.00030657486
# Target cost: 0.00031371252
# Target cost: 0.0003210321
# Target cost: 0.0003284862
# Target cost: 0.00033622145
# Target cost: 0.00034416054
# Target cost: 0.0003524773
# Target cost: 0.000361067
# Target cost: 0.0003699912
# Target cost: 0.00037932477
# Target cost: 0.00038902566
# Target cost: 0.00039892204
# Target cost: 0.00040908053
# Target cost: 0.00041962558
# Target cost: 0.00043077153
# Target cost: 0.00044247392
# Target cost: 0.0004547162
# Target cost: 0.00046762594
# Target cost: 0.00048122957
# Target cost: 0.0004956247
# Target cost: 0.0005108251
# Target cost: 0.00052709866
# Target cost: 0.0005443018
# Target cost: 0.00056247326
# Target cost: 0.000581985
# Target cost: 0.0006028745
# Target cost: 0.00062487804
# Target cost: 0.0006478882
# Target cost: 0.00067248254
# Target cost: 0.00069840165
# Target cost: 0.0007257741
# Target cost: 0.000754649
# Target cost: 0.0007856114
# Target cost: 0.0008188875
# Target cost: 0.0008544005
# Target cost: 0.00089251937
# Target cost: 0.0009339259
# Target cost: 0.0009795872
# Target cost: 0.0010289141
# Target cost: 0.0010825748
# Target cost: 0.001142404
# Target cost: 0.0012084102
# Target cost: 0.0012816465
# Target cost: 0.0013621452
# Target cost: 0.0014524285
# Target cost: 0.0015554606
# Target cost: 0.0016704737
# Target cost: 0.0018058
# Target cost: 0.0019725433
# Target cost: 0.0021774746
# Target cost: 0.0024196266
# Target cost: 0.0027028657
# Target cost: 0.0030658522
# Target cost: 0.0035213842
# Target cost: 0.0040573515
# Target cost: 0.0047145467
# Target cost: 0.0055261743
# Target cost: 0.0066145435
# Target cost: 0.008102531
# Target cost: 0.010137604
# Target cost: 0.013428697
# Target cost: 0.017009873
# Target cost: 0.027287478
# Target cost: 0.032250755
# Target cost: 0.06530983
# Target cost: 0.099304035
# Target cost: 0.4215518
# Target cost: 0.13091117
# Target cost: 0.9359146
# Target cost: 0.9963437

# %%
adv /= 2
adv += 0.5
adv *= 255

# %%
plt.imshow(adv[0].astype(np.uint8))
plt.show()

# %%
from PIL import Image
im = Image.fromarray(adv[0].astype(np.uint8))
im.save("./Imágenes/fakelemon.png")
